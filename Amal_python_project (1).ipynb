# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\cer\\Desktop\\MyPython\\mumbai.csv')

# %%
df
# Out:
#            price                                            Address    area  \
# 0     22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1     35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2     31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3     18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4     13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
# ...          ...                                                ...     ...
# 6250  19500000.0   Yari Road, Mumbai - Western Suburbs, Maharashtra   810.0
# 6251  22000000.0  502., Hari Om Nagar, Mumbai - North Mumbai, Ma...  1400.0
# 6252  20000000.0  Lokhandwala Complex, Andheri West, Lokhandwala...   750.0
# 6253  11000000.0         Sion, Mumbai - Central Mumbai, Maharashtra   700.0
# 6254  15000000.0    Mulund West, Mumbai - Central Line, Maharashtra   900.0
#
# ...

# %%
df.head()
# Out:
#         price                                            Address    area  \
# 0  22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1  35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2  31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3  18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4  13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
#
#     latitude  longitude  Bedrooms  Bathrooms  Balcony              Status  \
# 0  19.032800  72.896357       2.0        2.0      NaN  Under Construction
# 1  19.032800  72.896357       3.0        2.0      NaN  Under Construction
# 2  19.085600  72.909277       3.0        3.0      NaN  Under Construction
# 3  19.155756  72.846862       2.0        2.0      2.0       Ready to Move
# 4  19.177555  72.849887       2.0        2.0      NaN                 NaN
#
#        neworold  parking Furnished_status  Lift               Landmarks  \
# ...

# %%
df.Bedrooms.unique()
# Out:
# array([ 2.,  3.,  4.,  6.,  5.,  8.,  7., 10.])

# %%
selected_rows=df.iloc[0:20]

# %%
selected_columns=selected_rows[['price','Address','area','Landmarks']]

# %%
selected_columns.to_csv("C:\\Users\\cer\\Desktop\\MyPython\\op1.csv")

# %%
selected_columns.info
# Out:
# <bound method DataFrame.info of           price                                            Address    area  \
# 0    22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1    35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2    31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3    18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4    13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
# 5    13000000.0  Bhandup, Mumbai, Bhandup, Mumbai - Central Lin...   630.0
# 6    20700000.0  Siddharth Nagar, Goregaon West, Mumbai, Gorega...  1188.0
# 7    22900000.0  Goregaon West, Mumbai, Best Nagar - Goregaon W...   968.0
# 8    17000000.0  Wadala East, Mumbai, Wadala, Mumbai - Harbour ...   820.0
# 9    81000000.0  Worli, Mumbai, Worli, Mumbai - South Mumbai, M...  3260.0
# 10   46000000.0  near by nahur station, Mulund West, Mumbai - C...  2500.0
# ...

# %%
selected_columns.dtypes
# Out:
# price        float64
# Address       object
# area         float64
# Landmarks     object
# dtype: object

# %%
selected_columns.shape
# Out:
# (20, 4)

# %%
selected_columns.describe()
# Out:
#               price         area
# count  2.000000e+01    20.000000
# mean   3.231000e+07  1253.250000
# std    2.388939e+07   782.927494
# min    1.300000e+07   629.000000
# 25%    1.892500e+07   861.250000
# 50%    2.245000e+07   987.000000
# 75%    3.425000e+07  1114.500000
# max    1.020000e+08  3260.000000

# %%
sel_col_copy=selected_columns.copy()
sel_col_copy.head
# Out:
# <bound method NDFrame.head of           price                                            Address    area  \
# 0    22400000.0        Chembur, Mumbai - Harbour Line, Maharashtra   629.0
# 1    35000000.0        Chembur, Mumbai - Harbour Line, Maharashtra   974.0
# 2    31700000.0  Ghatkopar East, Mumbai - Central Line, Maharas...   968.0
# 3    18700000.0  Plot Number 283, Road Number 3, Jawahar Nagar,...   629.0
# 4    13500000.0  malad east, Malad East, Mumbai - North Mumbai,...  1090.0
# 5    13000000.0  Bhandup, Mumbai, Bhandup, Mumbai - Central Lin...   630.0
# 6    20700000.0  Siddharth Nagar, Goregaon West, Mumbai, Gorega...  1188.0
# 7    22900000.0  Goregaon West, Mumbai, Best Nagar - Goregaon W...   968.0
# 8    17000000.0  Wadala East, Mumbai, Wadala, Mumbai - Harbour ...   820.0
# 9    81000000.0  Worli, Mumbai, Worli, Mumbai - South Mumbai, M...  3260.0
# 10   46000000.0  near by nahur station, Mulund West, Mumbai - C...  2500.0
# ...

# %%
sel_col_copy.describe()
# Out:
#               price         area
# count  2.000000e+01    20.000000
# mean   3.231000e+07  1253.250000
# std    2.388939e+07   782.927494
# min    1.300000e+07   629.000000
# 25%    1.892500e+07   861.250000
# 50%    2.245000e+07   987.000000
# 75%    3.425000e+07  1114.500000
# max    1.020000e+08  3260.000000

# %%
sel_col_copy1=selected_rows[['price','area']]

# %%
sns.heatmap(sel_col_copy1.corr())
# Out:
# <Axes: >

# %%
sel_col_copy.Landmarks.unique()
# Out:
# array([nan, 'Laxmi Callista', 'near uper govind nagar',
#        'LBS road bhandup west 7 min walking from station',
#        'goregaon west', 'Near Ram Mandir railway station goregaon west',
#        'Dosti acres.', 'prime property', 'near nahur station',
#        'Fortis Hospital', 'Juhu', 'Rajawadi derasar', 'near datar colony',
#        'Near by mig cricket Club', 'Kandarpada Circle', 'Mulund west.',
#        'Near NES International school'], dtype=object)

# %%
sns.histplot(sel_col_copy.price)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.countplot(data=sel_col_copy, x='price',hue='area')
# Out:
# <Axes: xlabel='price', ylabel='count'>

# %%
sns.histplot(df.area)
# Out:
# <Axes: xlabel='area', ylabel='Count'>

# %%
df.value_counts(sel_col_copy.area)
# Out:
# area
# 629.0     2
# 968.0     2
# 1058.0    1
# 3180.0    1
# 2500.0    1
# 1500.0    1
# 1188.0    1
# 1090.0    1
# 1085.0    1
# 1020.0    1
# 630.0     1
# 1000.0    1
# 974.0     1
# 891.0     1
# 875.0     1
# 820.0     1
# 800.0     1
# 3260.0    1
# Name: count, dtype: int64

# %%
sns.countplot(sel_col_copy.price)
# Out:
# <Axes: ylabel='count'>

# %%
sns.barplot(x='price',y='Price_sqft',data=df)
# Out:
# <Axes: xlabel='price', ylabel='Price_sqft'>

# %%
sns.pairplot(df)
